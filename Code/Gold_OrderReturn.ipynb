# %%
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 6167d6db-4a5a-46c6-ba15-e874757f7563, 23, Finished, Available)

# %%
# %%sql
#
# create table if not exists Project_Lakehouse.Gold_OrderReturn
# (
#
# Order_ID  string,
# Return string,
# Order_Year int,
# Order_Month int,
# Created_TS TIMESTAMP,
# Modified_TS TIMESTAMP
#
# )
# using delta
# partitioned by(Order_Year,Order_Month)
# Out:
# StatementMeta(, 6167d6db-4a5a-46c6-ba15-e874757f7563, 36, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
Max_Date=spark.sql("select coalesce(max(Modified_TS),'1900-01-01') from Project_Lakehouse.gold_orderreturn").first()[0]
# Out:
# StatementMeta(, 82296693-5cad-4ff8-a364-705969cde26d, 3, Finished, Available)

# %%
Max_Date
# Out:
# StatementMeta(, 82296693-5cad-4ff8-a364-705969cde26d, 4, Finished, Available)
# '2024-02-04 18:14:19.91739'

# %%
df=spark.sql("""select Order_ID  ,
Return ,
Order_Year, 
Order_Month ,
Created_TS ,
Modified_TS 
from Project_Lakehouse.bronze_sales where Return="Yes" and Modified_TS>'{}'""".format(Max_Date))
# Out:
# StatementMeta(, 46dbd7d2-9b42-416f-a418-8e60d6f65bec, 19, Finished, Available)

# %%
df.createOrReplaceTempView("ViewReturn")
# Out:
# StatementMeta(, 46dbd7d2-9b42-416f-a418-8e60d6f65bec, 20, Finished, Available)

# %%
# %%sql
# insert into Project_Lakehouse.gold_orderreturn
# select * from ViewReturn
# Out:
# StatementMeta(, 46dbd7d2-9b42-416f-a418-8e60d6f65bec, 22, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
