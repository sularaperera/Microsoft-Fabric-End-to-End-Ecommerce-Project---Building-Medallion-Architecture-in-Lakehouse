# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 3, Finished, Available)

# %%
# %%sql
# create table if not EXISTS Project_Lakehouse.gold_date
# (
# BusinessDate Date,
# Business_Year int,
# Business_Month int,
# Business_Quarter int,
# Business_Week int
# )
# using DELTA
# PARTITIONED by (Business_Year)
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 4, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
start_date='2015-01-01'
end_date='2030-12-31'

date_diff=spark.sql("select date_diff('{}','{}')".format(end_date,start_date)).first()[0]
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 5, Finished, Available)

# %%
date_diff
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 6, Finished, Available)
# 5843

# %%
ID_Data=spark.range(0,date_diff)
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 7, Finished, Available)

# %%
date_data=ID_Data.selectExpr("date_add('{}',cast(id as int)) as BusinessDate".format(start_date))
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 8, Finished, Available)

# %%
date_data.createOrReplaceTempView("ViewDate")
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 9, Finished, Available)

# %%
# %%sql
#
# delete from Project_Lakehouse.gold_date;
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 10, Finished, Available)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# insert into Project_Lakehouse.gold_date
# select *,
# Year(BusinessDate) as Business_Year,
# Month(BusinessDate) as Business_Month,
# Quarter(BusinessDate) as Business_Quarter,
# weekday(BusinessDate) as Business_Week
#  from ViewDate
# Out:
# StatementMeta(, 27bd7a1c-05df-4035-9fc1-6d97424a71d9, 11, Finished, Available)
# <Spark SQL result set with 0 rows and 0 fields>
