# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, cf802cd5-48ac-44b7-8ce6-1c17f5f08380, 35, Finished, Available)

# %%
#mssparkutils.fs.help()
# Out:
# StatementMeta(, ecda7654-d652-47c1-b42b-79ecbab024cd, 3, Finished, Available)

# %%
mssparkutils.fs.mount("abfss://bb3ae42b-617a-4d5a-baf9-d45cf59b3f04@onelake.dfs.fabric.microsoft.com/ff98c3a6-7203-438e-b395-a08c628364e2/Files","/Files")
# Out:
# StatementMeta(, ecda7654-d652-47c1-b42b-79ecbab024cd, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 36840d5d-f207-4a3c-bb37-c4bf91823d6e)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, ecda7654-d652-47c1-b42b-79ecbab024cd, 11, Finished, Available)
# '/synfs/notebook/ecda7654-d652-47c1-b42b-79ecbab024cd/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, ecda7654-d652-47c1-b42b-79ecbab024cd, 12, Finished, Available)

# %%
for file in check_files:
    if file.path:
        mssparkutils.fs.mv(file.path,f"file://{mssparkutils.fs.getMountPath('/Files')}/Archive/")
# Out:
# StatementMeta(, ecda7654-d652-47c1-b42b-79ecbab024cd, 13, Finished, Available)
